# %%
# from langchain_anthropic import ChatAntropic
from langchain_anthropic import ChatAnthropic

from dotenv import load_dotenv

load_dotenv()

import os

os.environ['ANTRHOPIC_API_KEY'] =os.getenv("ANTRHOPIC_API_KEY")


api_key = os.getenv("ANTRHOPIC_API_KEY")

# %%
# pip install langchain_anthropic

# %%
model = ChatAnthropic(model="claude-3-5-sonnet-20241022",api_key=api_key)

# %%
model.invoke("hi")
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 model.invoke("hi")
#
# File f:\study\LangGraph_LangChain\venv\Lib\site-packages\langchain_core\language_models\chat_models.py:372, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     360 @override
#     361 def invoke(
#     362     self,
#    (...)    367     **kwargs: Any,
#     368 ) -> BaseMessage:
#     369     config = ensure_config(config)
#     370     return cast(
#     371         "ChatGeneration",
# --> 372         self.generate_prompt(
#     373             [self._convert_input(input)],
#     374             stop=stop,
#     375             callbacks=config.get("callbacks"),
#     376             tags=config.get("tags"),
#     377             metadata=config.get("metadata"),
#     378             run_name=config.get("run_name"),
# ...

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv

load_dotenv()



api_key = os.getenv("'GOOGLE_API_KEY'")

model = ChatGoogleGenerativeAI(model='gemini-1.5-pro')

result = model.invoke('What is the capital of India',api_key)

print(result.content)
# Out:
# ---------------------------------------------------------------------------
# InvalidArgument                           Traceback (most recent call last)
# File f:\study\LangGraph_LangChain\venv\Lib\site-packages\langchain_google_genai\chat_models.py:178, in _chat_with_retry.<locals>._chat_with_retry(**kwargs)
#     177 try:
# --> 178     return generation_method(**kwargs)
#     179 # Do not retry for these errors.
#
# File f:\study\LangGraph_LangChain\venv\Lib\site-packages\google\ai\generativelanguage_v1beta\services\generative_service\client.py:835, in GenerativeServiceClient.generate_content(self, request, model, contents, retry, timeout, metadata)
#     834 # Send the request.
# --> 835 response = rpc(
#     836     request,
#     837     retry=retry,
#     838     timeout=timeout,
#     839     metadata=metadata,
#     840 )
#     842 # Done; return the response.
#
# ...

# %%
from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint
from dotenv import load_dotenv

load_dotenv()
import os
os.environ['HUGGINGFACEHUB_API_TOKEN'] =os.getenv("HUGGINGFACEHUB_API_TOKEN")
# api_key = os.getenv("HUGGINGFACEHUB_API_TOKEN")
llm = HuggingFaceEndpoint(
    repo_id="TinyLlama/TinyLlama-1.1B-Chat-v1.0",
    task="text-generation",

)

model = ChatHuggingFace(llm=llm)

result = model.invoke("What is the capital of India")

print(result.content)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[4], line 16
#       8 llm = HuggingFaceEndpoint(
#       9     repo_id="TinyLlama/TinyLlama-1.1B-Chat-v1.0",
#      10     task="text-generation",
#      11
#      12 )
#      14 model = ChatHuggingFace(llm=llm)
# ---> 16 result = model.invoke("What is the capital of India")
#      18 print(result.content)
#      22 from langchain_huggingface.llms import HuggingFacePipeline
#
# File f:\study\LangGraph_LangChain\venv\Lib\site-packages\langchain_core\language_models\chat_models.py:372, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     360 @override
#     361 def invoke(
#     362     self,
#    (...)    367     **kwargs: Any,
#     368 ) -> BaseMessage:
#     369     config = ensure_config(config)
#     370     return cast(
#     371         "ChatGeneration",
# --> 372         self.generate_prompt(
# ...

# %%
from langchain_huggingface.llms import HuggingFacePipeline


# it will download the model locally
hf = HuggingFacePipeline.from_model_id(
    model_id="gpt2",
    task="text-generation",
    pipeline_kwargs={"max_new_tokens": 10},
)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File f:\study\LangGraph_LangChain\venv\Lib\site-packages\huggingface_hub\file_download.py:119, in are_symlinks_supported(cache_dir)
#     118 try:
# --> 119     os.symlink(relative_src, dst_path)
#     120 except OSError:
#     121     # Likely running on Windows
#
# OSError: [WinError 1314] A required privilege is not held by the client: 'dummy_file_src' -> 'C:\\Users\\ANKIT\\.cache\\huggingface\\hub\\models--gpt2\\tmpllrb1o_a\\dummy_file_dst'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 3
#       1 from langchain_huggingface.llms import HuggingFacePipeline
# ----> 3 hf = HuggingFacePipeline.from_model_id(
#       4     model_id="gpt2",
#       5     task="text-generation",
# ...

# %%
result = hf.invoke("What is the capital of India")

print(result.content)

# %%
model = ChatHuggingFace(llm=llm)

result = model.invoke("What is the capital of India")

print(result.content)
