# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## output parse can work in strucuture llm and unstructure llm output models
#
# # Type of the Parser
#
# StrOutput parser
#
# Json Output
#
# StructuredOutPut Parser
#
# Pydantic OutputParser

# %% [markdown]
# # StrOutput Parser
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# why we need this parse if we do with
#
# result.content  will give the same result as StrOutPut Parser
#
#
# Answere :::

# %% [markdown]
# json parse does not enforce the schema mean it will not give the desined schema every time
#
#
#
# but we solved using `StructureParser`
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# in structureParse we cannot to do data validation
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
