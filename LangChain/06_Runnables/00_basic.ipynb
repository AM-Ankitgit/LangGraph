# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # why we need
#
# - To unify, simplify, and scale chain-building by giving every component a shared interface with support for async, streaming, logging, and composition.
#
# It’s not mandatory, but it greatly improves developer experience.
#
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# `in Runnable passthrogh :`
# it is a special runnable primitive that simply returns the input as output without modifying it
#
#
# `output ==  input `
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
