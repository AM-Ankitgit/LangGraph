# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# simple chain
# ✅ Why Use Parallel Chain Instead of Sequential?
# Because sequential chains wait for each step, they’re slower. Parallel chains:
#
# Improve performance (run multiple things at once)
#
# Are useful when outputs are independent
#
# Reduce latency in apps (especially with multiple LLM calls)
