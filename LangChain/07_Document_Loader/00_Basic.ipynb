# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# text loader create one single object for entire file
#
# which mean entire data will be loaded in single list
# ![image.png](attachment:image.png)

# %% [markdown]
# In pypdf loader it create document object based on the mumber of page present in pdf
#
# suppose 10 pages then  10 document object
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# https://python.langchain.com/docs/concepts/document_loaders/

# %% [markdown]
# <!-- https://python.langchain.com/docs/concepts/document_loaders/ -->

# %% [markdown]
# # To load multiple file from folder
#
# Directory Loader

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
