# %%
# Retriever is function

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Question

# what is difference between this method that we use 
# first method
retriever = vectorstore.as_retriever(search_kwargs={"k": 2})
query = "What is Chroma used for?"
results = retriever.invoke(query)


# second method

vector_store.similarity_search_with_score(
    query="",
    filter={"team": "Royal Challengers Bangalore"} # used big Capital K
)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # MMR
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # MQR
# IT SOLVE THE AMMBIQUITY
# ![image.png](attachment:image.png)

# %% [markdown]
# # CCR
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
