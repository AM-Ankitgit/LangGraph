# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import asyncio

async def greet():
    print("Hello...")
    await asyncio.sleep(2)  # Simulate a delay (e.g., network call)
    print("...World!")

# Run the async function
asyncio.run(greet)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 9
#       6     print("...World!")
#       8 # Run the async function
# ----> 9 asyncio.run(greet)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\asyncio\runners.py:190, in run(main, debug, loop_factory)
#     161 """Execute the coroutine and return the result.
#     162
#     163 This function runs the passed coroutine, taking care of
#    (...)    186     asyncio.run(main())
#     187 """
#     188 if events._get_running_loop() is not None:
#     189     # fail fast with short traceback
# --> 190     raise RuntimeError(
#     191         "asyncio.run() cannot be called from a running event loop")
#     193 with Runner(debug=debug, loop_factory=loop_factory) as runner:
#     194     return runner.run(main)
#
# RuntimeError: asyncio.run() cannot be called from a running event loop

# %%
import asyncio

# !pip install nest_asyncio


import aiohttp
from bs4 import BeautifulSoup

# List of URLs to scrape
urls = [
    "https://example.com",
    "https://httpbin.org/html",
    "https://www.python.org",
]

# Async function to fetch a URL
async def fetch(session, url):
    async with session.get(url) as response:
        html = await response.text()
        soup = BeautifulSoup(html, 'html.parser')
        title = soup.title.string if soup.title else "No title found"
        print(f"URL: {url} | Title: {title}")

# Main async function
async def main():
    async with aiohttp.ClientSession() as session:
        tasks = [fetch(session, url) for url in urls]
        await asyncio.gather(*tasks)  # Run all tasks concurrently

# Run the main async function
asyncio.run(main())
# Out:
# Requirement already satisfied: nest_asyncio in f:\study\langgraph_langchain\llmenv\lib\site-packages (1.6.0)
# [notice] A new release of pip is available: 23.2.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 31
#      28         await asyncio.gather(*tasks)  # Run all tasks concurrently
#      30 # Run the main async function
# ---> 31 asyncio.run(main())
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\asyncio\runners.py:190, in run(main, debug, loop_factory)
#     161 """Execute the coroutine and return the result.
#     162
#     163 This function runs the passed coroutine, taking care of
#    (...)    186     asyncio.run(main())
#     187 """
#     188 if events._get_running_loop() is not None:
#     189     # fail fast with short traceback
# --> 190     raise RuntimeError(
#     191         "asyncio.run() cannot be called from a running event loop")
#     193 with Runner(debug=debug, loop_factory=loop_factory) as runner:
#     194     return runner.run(main)
#
# RuntimeError: asyncio.run() cannot be called from a running event loop
# C:\Users\ANKIT\AppData\Local\Programs\Python\Python312\Lib\re\__init__.py:260: RuntimeWarning: coroutine 'greet' was never awaited
#   return pattern.translate(_special_chars_map)
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\ANKIT\AppData\Local\Programs\Python\Python312\Lib\re\__init__.py:260: RuntimeWarning: coroutine 'main' was never awaited
#   return pattern.translate(_special_chars_map)
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback

# %% [markdown]
# # tool calling
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
